# %% [markdown]
# # Data acquisition notebook
#
# Uses:
#     - Spotify API
#     - Spotipy

# %% [markdown]
# ## 1. Setup Spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

cid = "c7bb8703bc95445ca48b090c017cdc63"
secret = "49b2047ed46d4ed5b47d6b6523884b90"

client_cred_manager = SpotifyClientCredentials(client_id = cid, client_secret = secret)
sp = spotipy.Spotify(client_credentials_manager = client_cred_manager)

# %% [markdown]
# Data acquisition will be split in two.
#
# First create a dataframe with track IDs, then a second dataframe with all audio-features.

# %% [markdown]
# ## 2. Collect track ID

# %%
import timeit
start = timeit.default_timer()

# lists to store extracted information
artist_names = []
track_names = []
track_ids = []
popularities = []


# some info
# for spotipy.search: 
    # q : query
    # type : album, artist, track, playlist
    # limit : how many to return
    # offset : index of first item to return

# results now is a type dict object
# all relevant information we seek is stored under >tracks>items> ...
# where ... contains album, name, etc
for i in range(0, 10000, 50):
    results = sp.search(q = 'year:2019', type = 'track', limit = 50, offset = i)
    for i, t in enumerate(results['tracks']['items']): # the reason why i, t (tuple) is needed is because
        artist_names.append(t['artists'][0]['name'])   #i iterates on 'tracks' and t on 'items'
        track_names.append(t['name'])
        track_ids.append(t['id'])
        popularities.append(t['popularity'])

stop = timeit.default_timer()

print("This took", (stop-start), " seconds to run.")
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# This took 101.48866940000016  seconds to run.

# %%
# sanity check
print("Are there any new Led Zepellin songs? \nThere are %s new songs by the zeps..." % artist_names.count("Led Zepellin"))

print("\nWe collected %s tracks for our records. As expected?" %len(track_names))
# Out:
# Are there any new Led Zepellin songs?
# There are 0 new songs by the zeps...
#
# We collected 10000 tracks for our records. As expected?

# %% [markdown]
# Okay, this looks good. Time to wrangle our data a bit.
#
# Lets start by first making our lists into a panda dataframe.

# %%
df_tracks = pd.DataFrame(
    {
    'artist': artist_names,
    'track': track_names,
    'track_id': track_ids,
    'popularity': popularities
    }
)

# %%
df_tracks.sort_values("popularity", ascending= False).head()

# I only know of Billie Eilish and Sam Smith. Not bad I guess!
# Out:
#            artist              track                 trackid  popularity
# 2    Shawn Mendes           Señorita  0TK2YIli7K1leLovkQiNik         100
# 42       Anuel AA              China  2ksOAxtIxY8yElEWw8RhgK          97
# 58    Tones and I       Dance Monkey  5ZULALImTm80tzUbYQYM9d          96
# 6   Billie Eilish            bad guy  2Fxmhks0bxGSBdJ92vM42m          96
# 13      Sam Smith  How Do You Sleep?  6b2RcmUt1g9N9mQ3CbjX2Y          96

# %%
print(df_tracks.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
# artist        10000 non-null object
# track         10000 non-null object
# trackid       10000 non-null object
# popularity    10000 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB
# None

# %% [markdown]
# It's important to check whether we have duplicates.
# Spotify API does not assign identical trackIDs to same songs coming from a single and an album. They treat them as different entities in the dataframe. We should fix this.

# %%
grouped = df_tracks.groupby(["artist", "track"], as_index = True).size()
# this groups the dataframe, first by artist, then by track and measures the size of the final grouping.
# if a song is repeated then the group artist,track will be of size > 1 since track will appear at least 2 times.

# %%
grouped[grouped > 1] # to see which are repeated
grouped[grouped > 1].count() # to count them
# Out:
# 1202

# %%
# drop duplicates, again same logic on subsecting
df_tracks.drop_duplicates(subset = ['artist', 'track'], inplace=True)

# %%
# make sure no repeatitions are left
grouped_after_dropping = df_tracks.groupby(['artist','track'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %% [markdown]
# ## 3. Time to collect audio features
#
# As we have collected our track information, it is time to collect the relevant audio features for the tracks in our list.
# This needs to be done separately. Again same logic in our previous pull.

# %%
# start timer
start = timeit.default_timer()

# initialise lists 
rows = [] 
steps = 100 # 100 to begin. causes problems otherwise for the API call
NA_counter = 0 # some tracks dont have information.

for i in range(0, len(df_tracks['trackid']), steps):
    batch = df_tracks['trackid'][i:i+steps] # selects 'steps' number of tracks from the df; no repetition since step increment in range
    features = sp.audio_features(batch) # features is now [[features], [features], ..., ..., ...]
    for i, t in enumerate(features):
        if t == None:
            NA_counter += 1
        else:
            rows.append(t)
            
            
stop = timeit.default_timer()

print("This took %s in seconds to complete." % (stop-start))
# Out:
# This took 12.917574500000228 in seconds to complete.

# %%
rows
# Out:
# [{'danceability': 0.715,
#   'energy': 0.624,
#   'key': 4,
#   'loudness': -3.046,
#   'mode': 0,
#   'speechiness': 0.114,
#   'acousticness': 0.11,
#   'instrumentalness': 0,
#   'liveness': 0.123,
#   'valence': 0.412,
#   'tempo': 158.087,
#   'type': 'audio_features',
#   'id': '5qmq61DAAOUaW8AUo8xKhh',
#   'uri': 'spotify:track:5qmq61DAAOUaW8AUo8xKhh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qmq61DAAOUaW8AUo8xKhh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qmq61DAAOUaW8AUo8xKhh',
#   'duration_ms': 173325,
#   'time_signature': 4},
#  {'danceability': 0.831,
#   'energy': 0.502,
#   'key': 10,
#   'loudness': -4.045,
#   'mode': 0,
#   'speechiness': 0.046,
#   'acousticness': 0.101,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.101,
#   'tempo': 100.541,
#   'type': 'audio_features',
#   'id': '5ry2OE6R2zPQFDO85XkgRb',
#   'uri': 'spotify:track:5ry2OE6R2zPQFDO85XkgRb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ry2OE6R2zPQFDO85XkgRb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ry2OE6R2zPQFDO85XkgRb',
#   'duration_ms': 205427,
#   'time_signature': 4},
#  {'danceability': 0.759,
#   'energy': 0.54,
#   'key': 9,
#   'loudness': -6.039,
#   'mode': 0,
#   'speechiness': 0.0287,
#   'acousticness': 0.037,
#   'instrumentalness': 0,
#   'liveness': 0.0945,
#   'valence': 0.75,
#   'tempo': 116.947,
#   'type': 'audio_features',
#   'id': '0TK2YIli7K1leLovkQiNik',
#   'uri': 'spotify:track:0TK2YIli7K1leLovkQiNik',
#   'track_href': 'https://api.spotify.com/v1/tracks/0TK2YIli7K1leLovkQiNik',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0TK2YIli7K1leLovkQiNik',
#   'duration_ms': 190960,
#   'time_signature': 4},
#  {'danceability': 0.703,
#   'energy': 0.594,
#   'key': 5,
#   'loudness': -6.146,
#   'mode': 0,
#   'speechiness': 0.0752,
#   'acousticness': 0.342,
#   'instrumentalness': 0,
#   'liveness': 0.123,
#   'valence': 0.475,
#   'tempo': 153.848,
#   'type': 'audio_features',
#   'id': '6fTt0CH2t0mdeB2N9XFG5r',
#   'uri': 'spotify:track:6fTt0CH2t0mdeB2N9XFG5r',
#   'track_href': 'https://api.spotify.com/v1/tracks/6fTt0CH2t0mdeB2N9XFG5r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6fTt0CH2t0mdeB2N9XFG5r',
#   'duration_ms': 114893,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.762,
#   'key': 0,
#   'loudness': -3.497,
#   'mode': 1,
#   'speechiness': 0.0395,
#   'acousticness': 0.192,
#   'instrumentalness': 0.00244,
#   'liveness': 0.0863,
#   'valence': 0.553,
#   'tempo': 120.042,
#   'type': 'audio_features',
#   'id': '21jGcNKet2qwijlDFuPiPb',
#   'uri': 'spotify:track:21jGcNKet2qwijlDFuPiPb',
#   'track_href': 'https://api.spotify.com/v1/tracks/21jGcNKet2qwijlDFuPiPb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21jGcNKet2qwijlDFuPiPb',
#   'duration_ms': 215280,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.642,
#   'key': 7,
#   'loudness': -6.257,
#   'mode': 0,
#   'speechiness': 0.287,
#   'acousticness': 0.0204,
#   'instrumentalness': 0,
#   'liveness': 0.0658,
#   'valence': 0.226,
#   'tempo': 179.974,
#   'type': 'audio_features',
#   'id': '6EOKwHETwSkZ9gW2b6ASE0',
#   'uri': 'spotify:track:6EOKwHETwSkZ9gW2b6ASE0',
#   'track_href': 'https://api.spotify.com/v1/tracks/6EOKwHETwSkZ9gW2b6ASE0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6EOKwHETwSkZ9gW2b6ASE0',
#   'duration_ms': 131240,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '2Fxmhks0bxGSBdJ92vM42m',
#   'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#   'duration_ms': 194088,
#   'time_signature': 4},
#  {'danceability': 0.855,
#   'energy': 0.651,
#   'key': 0,
#   'loudness': -8.044,
#   'mode': 0,
#   'speechiness': 0.235,
#   'acousticness': 0.063,
#   'instrumentalness': 0,
#   'liveness': 0.0772,
#   'valence': 0.559,
#   'tempo': 111.997,
#   'type': 'audio_features',
#   'id': '5Z8HZM6iQMhhqyPcCGY5g9',
#   'uri': 'spotify:track:5Z8HZM6iQMhhqyPcCGY5g9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Z8HZM6iQMhhqyPcCGY5g9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Z8HZM6iQMhhqyPcCGY5g9',
#   'duration_ms': 193027,
#   'time_signature': 4},
#  {'danceability': 0.876,
#   'energy': 0.662,
#   'key': 2,
#   'loudness': -6.482,
#   'mode': 0,
#   'speechiness': 0.426,
#   'acousticness': 0.0608,
#   'instrumentalness': 0,
#   'liveness': 0.127,
#   'valence': 0.844,
#   'tempo': 75.445,
#   'type': 'audio_features',
#   'id': '2gwkD6igEhQbDQegRCcdoB',
#   'uri': 'spotify:track:2gwkD6igEhQbDQegRCcdoB',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gwkD6igEhQbDQegRCcdoB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gwkD6igEhQbDQegRCcdoB',
#   'duration_ms': 163320,
#   'time_signature': 4},
#  {'danceability': 0.931,
#   'energy': 0.502,
#   'key': 0,
#   'loudness': -9.311,
#   'mode': 0,
#   'speechiness': 0.353,
#   'acousticness': 0.0389,
#   'instrumentalness': 0,
#   'liveness': 0.0912,
#   'valence': 0.712,
#   'tempo': 94.999,
#   'type': 'audio_features',
#   'id': '4sjiIpEv617LDXaidKioOI',
#   'uri': 'spotify:track:4sjiIpEv617LDXaidKioOI',
#   'track_href': 'https://api.spotify.com/v1/tracks/4sjiIpEv617LDXaidKioOI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4sjiIpEv617LDXaidKioOI',
#   'duration_ms': 176640,
#   'time_signature': 4},
#  {'danceability': 0.501,
#   'energy': 0.405,
#   'key': 1,
#   'loudness': -5.679,
#   'mode': 1,
#   'speechiness': 0.0319,
#   'acousticness': 0.751,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.446,
#   'tempo': 109.891,
#   'type': 'audio_features',
#   'id': '7qEHsqek33rTcFNT9PFqLf',
#   'uri': 'spotify:track:7qEHsqek33rTcFNT9PFqLf',
#   'track_href': 'https://api.spotify.com/v1/tracks/7qEHsqek33rTcFNT9PFqLf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qEHsqek33rTcFNT9PFqLf',
#   'duration_ms': 182161,
#   'time_signature': 4},
#  {'danceability': 0.843,
#   'energy': 0.391,
#   'key': 2,
#   'loudness': -7.899,
#   'mode': 1,
#   'speechiness': 0.0845,
#   'acousticness': 0.181,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.496,
#   'tempo': 129.972,
#   'type': 'audio_features',
#   'id': '51Fjme0JiitpyXKuyQiCDo',
#   'uri': 'spotify:track:51Fjme0JiitpyXKuyQiCDo',
#   'track_href': 'https://api.spotify.com/v1/tracks/51Fjme0JiitpyXKuyQiCDo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51Fjme0JiitpyXKuyQiCDo',
#   'duration_ms': 160627,
#   'time_signature': 4},
#  {'danceability': 0.4,
#   'energy': 0.795,
#   'key': 10,
#   'loudness': -3.731,
#   'mode': 0,
#   'speechiness': 0.461,
#   'acousticness': 0.119,
#   'instrumentalness': 0,
#   'liveness': 0.159,
#   'valence': 0.702,
#   'tempo': 190.097,
#   'type': 'audio_features',
#   'id': '0Ryd8975WihbObpp5cPW1t',
#   'uri': 'spotify:track:0Ryd8975WihbObpp5cPW1t',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Ryd8975WihbObpp5cPW1t',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Ryd8975WihbObpp5cPW1t',
#   'duration_ms': 186107,
#   'time_signature': 4},
#  {'danceability': 0.477,
#   'energy': 0.682,
#   'key': 1,
#   'loudness': -4.931,
#   'mode': 0,
#   'speechiness': 0.0925,
#   'acousticness': 0.153,
#   'instrumentalness': 0,
#   'liveness': 0.0763,
#   'valence': 0.345,
#   'tempo': 110.567,
#   'type': 'audio_features',
#   'id': '6b2RcmUt1g9N9mQ3CbjX2Y',
#   'uri': 'spotify:track:6b2RcmUt1g9N9mQ3CbjX2Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/6b2RcmUt1g9N9mQ3CbjX2Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6b2RcmUt1g9N9mQ3CbjX2Y',
#   'duration_ms': 202205,
#   'time_signature': 5},
#  {'danceability': 0.778,
#   'energy': 0.559,
#   'key': 6,
#   'loudness': -7.109,
#   'mode': 0,
#   'speechiness': 0.0776,
#   'acousticness': 0.128,
#   'instrumentalness': 0,
#   'liveness': 0.399,
#   'valence': 0.678,
#   'tempo': 129.989,
#   'type': 'audio_features',
#   'id': '7aiClxsDWFRQ0Kzk5KI5ku',
#   'uri': 'spotify:track:7aiClxsDWFRQ0Kzk5KI5ku',
#   'track_href': 'https://api.spotify.com/v1/tracks/7aiClxsDWFRQ0Kzk5KI5ku',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7aiClxsDWFRQ0Kzk5KI5ku',
#   'duration_ms': 185093,
#   'time_signature': 1},
#  {'danceability': 0.698,
#   'energy': 0.454,
#   'key': 1,
#   'loudness': -6.756,
#   'mode': 0,
#   'speechiness': 0.151,
#   'acousticness': 0.123,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.137,
#   'tempo': 92.932,
#   'type': 'audio_features',
#   'id': '6XHVuErjQ4XNm6nDPVCxVX',
#   'uri': 'spotify:track:6XHVuErjQ4XNm6nDPVCxVX',
#   'track_href': 'https://api.spotify.com/v1/tracks/6XHVuErjQ4XNm6nDPVCxVX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6XHVuErjQ4XNm6nDPVCxVX',
#   'duration_ms': 260640,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.586,
#   'key': 4,
#   'loudness': -6.946,
#   'mode': 0,
#   'speechiness': 0.147,
#   'acousticness': 0.0247,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.179,
#   'tempo': 97.981,
#   'type': 'audio_features',
#   'id': '7DcvwMAiqKJQD1rrdfxSDx',
#   'uri': 'spotify:track:7DcvwMAiqKJQD1rrdfxSDx',
#   'track_href': 'https://api.spotify.com/v1/tracks/7DcvwMAiqKJQD1rrdfxSDx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DcvwMAiqKJQD1rrdfxSDx',
#   'duration_ms': 200107,
#   'time_signature': 4},
#  {'danceability': 0.974,
#   'energy': 0.596,
#   'key': 6,
#   'loudness': -8.888,
#   'mode': 1,
#   'speechiness': 0.184,
#   'acousticness': 0.0976,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.892,
#   'tempo': 111.959,
#   'type': 'audio_features',
#   'id': '1GeNui6m825V8jP4uKiIaH',
#   'uri': 'spotify:track:1GeNui6m825V8jP4uKiIaH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1GeNui6m825V8jP4uKiIaH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GeNui6m825V8jP4uKiIaH',
#   'duration_ms': 149040,
#   'time_signature': 4},
#  {'danceability': 0.617,
#   'energy': 0.684,
#   'key': 0,
#   'loudness': -3.618,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.0545,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.295,
#   'tempo': 132.113,
#   'type': 'audio_features',
#   'id': '05mDaV9Vb3wrzjF6OPZnhq',
#   'uri': 'spotify:track:05mDaV9Vb3wrzjF6OPZnhq',
#   'track_href': 'https://api.spotify.com/v1/tracks/05mDaV9Vb3wrzjF6OPZnhq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05mDaV9Vb3wrzjF6OPZnhq',
#   'duration_ms': 150867,
#   'time_signature': 4},
#  {'danceability': 0.772,
#   'energy': 0.639,
#   'key': 1,
#   'loudness': -7.119,
#   'mode': 1,
#   'speechiness': 0.467,
#   'acousticness': 0.15,
#   'instrumentalness': 0,
#   'liveness': 0.0698,
#   'valence': 0.261,
#   'tempo': 168.112,
#   'type': 'audio_features',
#   'id': '6uFn47ACjqYkc0jADwEdj1',
#   'uri': 'spotify:track:6uFn47ACjqYkc0jADwEdj1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6uFn47ACjqYkc0jADwEdj1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6uFn47ACjqYkc0jADwEdj1',
#   'duration_ms': 166560,
#   'time_signature': 4},
#  {'danceability': 0.499,
#   'energy': 0.8,
#   'key': 1,
#   'loudness': -2.665,
#   'mode': 0,
#   'speechiness': 0.0502,
#   'acousticness': 0.0906,
#   'instrumentalness': 0,
#   'liveness': 0.147,
#   'valence': 0.272,
#   'tempo': 139.919,
#   'type': 'audio_features',
#   'id': '7CZyCXKG6d5ALeq41sLzbw',
#   'uri': 'spotify:track:7CZyCXKG6d5ALeq41sLzbw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7CZyCXKG6d5ALeq41sLzbw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7CZyCXKG6d5ALeq41sLzbw',
#   'duration_ms': 229573,
#   'time_signature': 4},
#  {'danceability': 0.359,
#   'energy': 0.543,
#   'key': 7,
#   'loudness': -7.582,
#   'mode': 1,
#   'speechiness': 0.0919,
#   'acousticness': 0.492,
#   'instrumentalness': 1.58e-05,
#   'liveness': 0.118,
#   'valence': 0.453,
#   'tempo': 68.534,
#   'type': 'audio_features',
#   'id': '1dGr1c8CrMLDpV6mPbImSI',
#   'uri': 'spotify:track:1dGr1c8CrMLDpV6mPbImSI',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dGr1c8CrMLDpV6mPbImSI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dGr1c8CrMLDpV6mPbImSI',
#   'duration_ms': 221307,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.648,
#   'key': 5,
#   'loudness': -8.113,
#   'mode': 0,
#   'speechiness': 0.187,
#   'acousticness': 0.124,
#   'instrumentalness': 0,
#   'liveness': 0.0802,
#   'valence': 0.548,
#   'tempo': 92.977,
#   'type': 'audio_features',
#   'id': '4evmHXcjt3bTUHD1cvny97',
#   'uri': 'spotify:track:4evmHXcjt3bTUHD1cvny97',
#   'track_href': 'https://api.spotify.com/v1/tracks/4evmHXcjt3bTUHD1cvny97',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4evmHXcjt3bTUHD1cvny97',
#   'duration_ms': 197867,
#   'time_signature': 4},
#  {'danceability': 0.894,
#   'energy': 0.511,
#   'key': 2,
#   'loudness': -4.768,
#   'mode': 1,
#   'speechiness': 0.42,
#   'acousticness': 0.0251,
#   'instrumentalness': 0,
#   'liveness': 0.14,
#   'valence': 0.568,
#   'tempo': 120.08,
#   'type': 'audio_features',
#   'id': '67XyC1GdSkKb9sbRRkUDXS',
#   'uri': 'spotify:track:67XyC1GdSkKb9sbRRkUDXS',
#   'track_href': 'https://api.spotify.com/v1/tracks/67XyC1GdSkKb9sbRRkUDXS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67XyC1GdSkKb9sbRRkUDXS',
#   'duration_ms': 176632,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.653,
#   'key': 5,
#   'loudness': -3.875,
#   'mode': 1,
#   'speechiness': 0.081,
#   'acousticness': 0.456,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.163,
#   'tempo': 150.068,
#   'type': 'audio_features',
#   'id': '0t3ZvGKlmYmVsDzBJAXK8C',
#   'uri': 'spotify:track:0t3ZvGKlmYmVsDzBJAXK8C',
#   'track_href': 'https://api.spotify.com/v1/tracks/0t3ZvGKlmYmVsDzBJAXK8C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0t3ZvGKlmYmVsDzBJAXK8C',
#   'duration_ms': 174853,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.674,
#   'key': 6,
#   'loudness': -4.169,
#   'mode': 1,
#   'speechiness': 0.21,
#   'acousticness': 0.0588,
#   'instrumentalness': 0,
#   'liveness': 0.0955,
#   'valence': 0.667,
#   'tempo': 76.388,
#   'type': 'audio_features',
#   'id': '0Xek5rqai2jcOWCYWJfVCF',
#   'uri': 'spotify:track:0Xek5rqai2jcOWCYWJfVCF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Xek5rqai2jcOWCYWJfVCF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Xek5rqai2jcOWCYWJfVCF',
#   'duration_ms': 196760,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.721,
#   'key': 1,
#   'loudness': -5.248,
#   'mode': 1,
#   'speechiness': 0.0449,
#   'acousticness': 0.00268,
#   'instrumentalness': 6.51e-06,
#   'liveness': 0.0898,
#   'valence': 0.317,
#   'tempo': 102.914,
#   'type': 'audio_features',
#   'id': '3NkJNL3WqO1Lqc3uNDxvCN',
#   'uri': 'spotify:track:3NkJNL3WqO1Lqc3uNDxvCN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3NkJNL3WqO1Lqc3uNDxvCN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3NkJNL3WqO1Lqc3uNDxvCN',
#   'duration_ms': 190107,
#   'time_signature': 4},
#  {'danceability': 0.872,
#   'energy': 0.814,
#   'key': 0,
#   'loudness': -4.568,
#   'mode': 1,
#   'speechiness': 0.155,
#   'acousticness': 0.00485,
#   'instrumentalness': 1.96e-06,
#   'liveness': 0.214,
#   'valence': 0.57,
#   'tempo': 98.985,
#   'type': 'audio_features',
#   'id': '5N1o6d8zGcSZSeMFkOUQOk',
#   'uri': 'spotify:track:5N1o6d8zGcSZSeMFkOUQOk',
#   'track_href': 'https://api.spotify.com/v1/tracks/5N1o6d8zGcSZSeMFkOUQOk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5N1o6d8zGcSZSeMFkOUQOk',
#   'duration_ms': 199427,
#   'time_signature': 4},
#  {'danceability': 0.97,
#   'energy': 0.463,
#   'key': 10,
#   'loudness': -7.259,
#   'mode': 1,
#   'speechiness': 0.366,
#   'acousticness': 0.0957,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.46,
#   'tempo': 108.003,
#   'type': 'audio_features',
#   'id': '2nKYHpmwjLaEOXS3o7QMiz',
#   'uri': 'spotify:track:2nKYHpmwjLaEOXS3o7QMiz',
#   'track_href': 'https://api.spotify.com/v1/tracks/2nKYHpmwjLaEOXS3o7QMiz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2nKYHpmwjLaEOXS3o7QMiz',
#   'duration_ms': 142417,
#   'time_signature': 4},
#  {'danceability': 0.883,
#   'energy': 0.525,
#   'key': 2,
#   'loudness': -8.054,
#   'mode': 0,
#   'speechiness': 0.0633,
#   'acousticness': 0.189,
#   'instrumentalness': 0,
#   'liveness': 0.0971,
#   'valence': 0.312,
#   'tempo': 99.978,
#   'type': 'audio_features',
#   'id': '2zjGJ0dChMR0KxBZS15aqo',
#   'uri': 'spotify:track:2zjGJ0dChMR0KxBZS15aqo',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zjGJ0dChMR0KxBZS15aqo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zjGJ0dChMR0KxBZS15aqo',
#   'duration_ms': 174100,
#   'time_signature': 4},
#  {'danceability': 0.787,
#   'energy': 0.713,
#   'key': 7,
#   'loudness': -5.252,
#   'mode': 1,
#   'speechiness': 0.401,
#   'acousticness': 0.0849,
#   'instrumentalness': 0,
#   'liveness': 0.717,
#   'valence': 0.762,
#   'tempo': 175.041,
#   'type': 'audio_features',
#   'id': '4sWuPniHClkInYAnzXAYUF',
#   'uri': 'spotify:track:4sWuPniHClkInYAnzXAYUF',
#   'track_href': 'https://api.spotify.com/v1/tracks/4sWuPniHClkInYAnzXAYUF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4sWuPniHClkInYAnzXAYUF',
#   'duration_ms': 148759,
#   'time_signature': 4},
#  {'danceability': 0.837,
#   'energy': 0.364,
#   'key': 8,
#   'loudness': -11.713,
#   'mode': 1,
#   'speechiness': 0.276,
#   'acousticness': 0.149,
#   'instrumentalness': 0,
#   'liveness': 0.271,
#   'valence': 0.463,
#   'tempo': 123.984,
#   'type': 'audio_features',
#   'id': '2JvzF1RMd7lE3KmFlsyZD8',
#   'uri': 'spotify:track:2JvzF1RMd7lE3KmFlsyZD8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2JvzF1RMd7lE3KmFlsyZD8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JvzF1RMd7lE3KmFlsyZD8',
#   'duration_ms': 213594,
#   'time_signature': 4},
#  {'danceability': 0.562,
#   'energy': 0.502,
#   'key': 6,
#   'loudness': -10.269,
#   'mode': 0,
#   'speechiness': 0.255,
#   'acousticness': 0.323,
#   'instrumentalness': 0,
#   'liveness': 0.0757,
#   'valence': 0.322,
#   'tempo': 120.104,
#   'type': 'audio_features',
#   'id': '0UPBidRYcgJ2mjZlk08V8x',
#   'uri': 'spotify:track:0UPBidRYcgJ2mjZlk08V8x',
#   'track_href': 'https://api.spotify.com/v1/tracks/0UPBidRYcgJ2mjZlk08V8x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UPBidRYcgJ2mjZlk08V8x',
#   'duration_ms': 224000,
#   'time_signature': 1},
#  {'danceability': 0.732,
#   'energy': 0.463,
#   'key': 11,
#   'loudness': -6.972,
#   'mode': 0,
#   'speechiness': 0.0287,
#   'acousticness': 0.374,
#   'instrumentalness': 0,
#   'liveness': 0.194,
#   'valence': 0.397,
#   'tempo': 95.971,
#   'type': 'audio_features',
#   'id': '6moU77g9RQyMzHNuKEaQKq',
#   'uri': 'spotify:track:6moU77g9RQyMzHNuKEaQKq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6moU77g9RQyMzHNuKEaQKq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6moU77g9RQyMzHNuKEaQKq',
#   'duration_ms': 212607,
#   'time_signature': 4},
#  {'danceability': 0.53,
#   'energy': 0.538,
#   'key': 5,
#   'loudness': -6.672,
#   'mode': 1,
#   'speechiness': 0.0335,
#   'acousticness': 0.17,
#   'instrumentalness': 2.83e-06,
#   'liveness': 0.248,
#   'valence': 0.288,
#   'tempo': 148.051,
#   'type': 'audio_features',
#   'id': '44ADyYoY5liaRa3EOAl4uf',
#   'uri': 'spotify:track:44ADyYoY5liaRa3EOAl4uf',
#   'track_href': 'https://api.spotify.com/v1/tracks/44ADyYoY5liaRa3EOAl4uf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44ADyYoY5liaRa3EOAl4uf',
#   'duration_ms': 233654,
#   'time_signature': 4},
#  {'danceability': 0.554,
#   'energy': 0.498,
#   'key': 9,
#   'loudness': -8.866,
#   'mode': 1,
#   'speechiness': 0.0685,
#   'acousticness': 0.23,
#   'instrumentalness': 5.98e-06,
#   'liveness': 0.795,
#   'valence': 0.413,
#   'tempo': 79.635,
#   'type': 'audio_features',
#   'id': '5hVghJ4KaYES3BFUATCYn0',
#   'uri': 'spotify:track:5hVghJ4KaYES3BFUATCYn0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5hVghJ4KaYES3BFUATCYn0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hVghJ4KaYES3BFUATCYn0',
#   'duration_ms': 190067,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.887,
#   'key': 4,
#   'loudness': -3.967,
#   'mode': 1,
#   'speechiness': 0.0984,
#   'acousticness': 0.0192,
#   'instrumentalness': 1.21e-06,
#   'liveness': 0.3,
#   'valence': 0.881,
#   'tempo': 170.918,
#   'type': 'audio_features',
#   'id': '0rIAC4PXANcKmitJfoqmVm',
#   'uri': 'spotify:track:0rIAC4PXANcKmitJfoqmVm',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rIAC4PXANcKmitJfoqmVm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rIAC4PXANcKmitJfoqmVm',
#   'duration_ms': 193837,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.658,
#   'key': 0,
#   'loudness': -5.191,
#   'mode': 1,
#   'speechiness': 0.054,
#   'acousticness': 0.0767,
#   'instrumentalness': 0,
#   'liveness': 0.0901,
#   'valence': 0.633,
#   'tempo': 110.048,
#   'type': 'audio_features',
#   'id': '3RauEVgRgj1IuWdJ9fDs70',
#   'uri': 'spotify:track:3RauEVgRgj1IuWdJ9fDs70',
#   'track_href': 'https://api.spotify.com/v1/tracks/3RauEVgRgj1IuWdJ9fDs70',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3RauEVgRgj1IuWdJ9fDs70',
#   'duration_ms': 190360,
#   'time_signature': 4},
#  {'danceability': 0.878,
#   'energy': 0.619,
#   'key': 6,
#   'loudness': -5.56,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.0533,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.639,
#   'tempo': 136.041,
#   'type': 'audio_features',
#   'id': '2YpeDb67231RjR0MgVLzsG',
#   'uri': 'spotify:track:2YpeDb67231RjR0MgVLzsG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2YpeDb67231RjR0MgVLzsG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YpeDb67231RjR0MgVLzsG',
#   'duration_ms': 157067,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.623,
#   'key': 4,
#   'loudness': -2.253,
#   'mode': 1,
#   'speechiness': 0.0451,
#   'acousticness': 0.0667,
#   'instrumentalness': 0,
#   'liveness': 0.582,
#   'valence': 0.439,
#   'tempo': 88.042,
#   'type': 'audio_features',
#   'id': '4hPpVbbakQNv8YTHYaOJP4',
#   'uri': 'spotify:track:4hPpVbbakQNv8YTHYaOJP4',
#   'track_href': 'https://api.spotify.com/v1/tracks/4hPpVbbakQNv8YTHYaOJP4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4hPpVbbakQNv8YTHYaOJP4',
#   'duration_ms': 181824,
#   'time_signature': 4},
#  {'danceability': 0.405,
#   'energy': 0.646,
#   'key': 4,
#   'loudness': -3.206,
#   'mode': 0,
#   'speechiness': 0.0476,
#   'acousticness': 0.331,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.17,
#   'tempo': 130.218,
#   'type': 'audio_features',
#   'id': '7sWRlDoTDX8geTR8zzr2vt',
#   'uri': 'spotify:track:7sWRlDoTDX8geTR8zzr2vt',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sWRlDoTDX8geTR8zzr2vt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sWRlDoTDX8geTR8zzr2vt',
#   'duration_ms': 156267,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.603,
#   'key': 6,
#   'loudness': -6.736,
#   'mode': 0,
#   'speechiness': 0.0666,
#   'acousticness': 0.0948,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.207,
#   'tempo': 134.972,
#   'type': 'audio_features',
#   'id': '3XiNC94b4Tq1xwv70sQJGN',
#   'uri': 'spotify:track:3XiNC94b4Tq1xwv70sQJGN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3XiNC94b4Tq1xwv70sQJGN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XiNC94b4Tq1xwv70sQJGN',
#   'duration_ms': 243976,
#   'time_signature': 4},
#  {'danceability': 0.786,
#   'energy': 0.808,
#   'key': 7,
#   'loudness': -3.702,
#   'mode': 1,
#   'speechiness': 0.0882,
#   'acousticness': 0.0846,
#   'instrumentalness': 0.000289,
#   'liveness': 0.0822,
#   'valence': 0.609,
#   'tempo': 105.027,
#   'type': 'audio_features',
#   'id': '2ksOAxtIxY8yElEWw8RhgK',
#   'uri': 'spotify:track:2ksOAxtIxY8yElEWw8RhgK',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ksOAxtIxY8yElEWw8RhgK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ksOAxtIxY8yElEWw8RhgK',
#   'duration_ms': 301714,
#   'time_signature': 4},
#  {'danceability': 0.552,
#   'energy': 0.702,
#   'key': 9,
#   'loudness': -5.707,
#   'mode': 1,
#   'speechiness': 0.157,
#   'acousticness': 0.117,
#   'instrumentalness': 2.06e-05,
#   'liveness': 0.105,
#   'valence': 0.564,
#   'tempo': 169.994,
#   'type': 'audio_features',
#   'id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'uri': 'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1BxfuPKGuaTgP7aM0Bbdwr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1BxfuPKGuaTgP7aM0Bbdwr',
#   'duration_ms': 178427,
#   'time_signature': 4},
#  {'danceability': 0.61,
#   'energy': 0.624,
#   'key': 2,
#   'loudness': -4.773,
#   'mode': 1,
#   'speechiness': 0.309,
#   'acousticness': 0.6,
#   'instrumentalness': 2.12e-06,
#   'liveness': 0.243,
#   'valence': 0.244,
#   'tempo': 176.169,
#   'type': 'audio_features',
#   'id': '2TH65lNHgvLxCKXM3apjxI',
#   'uri': 'spotify:track:2TH65lNHgvLxCKXM3apjxI',
#   'track_href': 'https://api.spotify.com/v1/tracks/2TH65lNHgvLxCKXM3apjxI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TH65lNHgvLxCKXM3apjxI',
#   'duration_ms': 250534,
#   'time_signature': 4},
#  {'danceability': 0.771,
#   'energy': 0.671,
#   'key': 2,
#   'loudness': -5.617,
#   'mode': 1,
#   'speechiness': 0.0553,
#   'acousticness': 0.00929,
#   'instrumentalness': 0,
#   'liveness': 0.0637,
#   'valence': 0.714,
#   'tempo': 85.026,
#   'type': 'audio_features',
#   'id': '6RRNNciQGZEXnqk8SQ9yv5',
#   'uri': 'spotify:track:6RRNNciQGZEXnqk8SQ9yv5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6RRNNciQGZEXnqk8SQ9yv5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6RRNNciQGZEXnqk8SQ9yv5',
#   'duration_ms': 171360,
#   'time_signature': 4},
#  {'danceability': 0.806,
#   'energy': 0.558,
#   'key': 9,
#   'loudness': -6.46,
#   'mode': 1,
#   'speechiness': 0.0683,
#   'acousticness': 0.482,
#   'instrumentalness': 0,
#   'liveness': 0.0618,
#   'valence': 0.678,
#   'tempo': 95.016,
#   'type': 'audio_features',
#   'id': '322tcqPhma7F6hfCeLisx0',
#   'uri': 'spotify:track:322tcqPhma7F6hfCeLisx0',
#   'track_href': 'https://api.spotify.com/v1/tracks/322tcqPhma7F6hfCeLisx0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/322tcqPhma7F6hfCeLisx0',
#   'duration_ms': 198973,
#   'time_signature': 4},
#  {'danceability': 0.74,
#   'energy': 0.498,
#   'key': 11,
#   'loudness': -6.684,
#   'mode': 0,
#   'speechiness': 0.0456,
#   'acousticness': 0.0169,
#   'instrumentalness': 0.00282,
#   'liveness': 0.319,
#   'valence': 0.652,
#   'tempo': 98.016,
#   'type': 'audio_features',
#   'id': '7LzouaWGFCy4tkXDOOnEyM',
#   'uri': 'spotify:track:7LzouaWGFCy4tkXDOOnEyM',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LzouaWGFCy4tkXDOOnEyM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LzouaWGFCy4tkXDOOnEyM',
#   'duration_ms': 207039,
#   'time_signature': 4},
#  {'danceability': 0.294,
#   'energy': 0.505,
#   'key': 3,
#   'loudness': -8.106,
#   'mode': 1,
#   'speechiness': 0.042,
#   'acousticness': 0.12,
#   'instrumentalness': 0,
#   'liveness': 0.0977,
#   'valence': 0.357,
#   'tempo': 85.332,
#   'type': 'audio_features',
#   'id': '6wo37KVqFJhtuxPTpLCcfe',
#   'uri': 'spotify:track:6wo37KVqFJhtuxPTpLCcfe',
#   'track_href': 'https://api.spotify.com/v1/tracks/6wo37KVqFJhtuxPTpLCcfe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wo37KVqFJhtuxPTpLCcfe',
#   'duration_ms': 209893,
#   'time_signature': 1},
#  {'danceability': 0.367,
#   'energy': 0.111,
#   'key': 4,
#   'loudness': -14.084,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.978,
#   'instrumentalness': 3.97e-05,
#   'liveness': 0.0897,
#   'valence': 0.198,
#   'tempo': 82.642,
#   'type': 'audio_features',
#   'id': '43zdsphuZLzwA9k4DJhU0I',
#   'uri': 'spotify:track:43zdsphuZLzwA9k4DJhU0I',
#   'track_href': 'https://api.spotify.com/v1/tracks/43zdsphuZLzwA9k4DJhU0I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43zdsphuZLzwA9k4DJhU0I',
#   'duration_ms': 196077,
#   'time_signature': 4},
#  {'danceability': 0.667,
#   'energy': 0.583,
#   'key': 11,
#   'loudness': -5.127,
#   'mode': 0,
#   'speechiness': 0.0747,
#   'acousticness': 0.231,
#   'instrumentalness': 4.48e-05,
#   'liveness': 0.181,
#   'valence': 0.187,
#   'tempo': 92.043,
#   'type': 'audio_features',
#   'id': '6V9fHiv84WlVTg7CSnIVY2',
#   'uri': 'spotify:track:6V9fHiv84WlVTg7CSnIVY2',
#   'track_href': 'https://api.spotify.com/v1/tracks/6V9fHiv84WlVTg7CSnIVY2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6V9fHiv84WlVTg7CSnIVY2',
#   'duration_ms': 181806,
#   'time_signature': 4},
#  {'danceability': 0.899,
#   'energy': 0.811,
#   'key': 2,
#   'loudness': -6.294,
#   'mode': 1,
#   'speechiness': 0.258,
#   'acousticness': 0.000677,
#   'instrumentalness': 0,
#   'liveness': 0.0672,
#   'valence': 0.587,
#   'tempo': 105.038,
#   'type': 'audio_features',
#   'id': '5KBARWIxeMGkvUax9VtVC9',
#   'uri': 'spotify:track:5KBARWIxeMGkvUax9VtVC9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5KBARWIxeMGkvUax9VtVC9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KBARWIxeMGkvUax9VtVC9',
#   'duration_ms': 126446,
#   'time_signature': 4},
#  {'danceability': 0.812,
#   'energy': 0.519,
#   'key': 2,
#   'loudness': -4.823,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'acousticness': 0.379,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.554,
#   'tempo': 104.954,
#   'type': 'audio_features',
#   'id': '4a6q8CR2hzLk2plDkSxkfD',
#   'uri': 'spotify:track:4a6q8CR2hzLk2plDkSxkfD',
#   'track_href': 'https://api.spotify.com/v1/tracks/4a6q8CR2hzLk2plDkSxkfD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4a6q8CR2hzLk2plDkSxkfD',
#   'duration_ms': 165714,
#   'time_signature': 4},
#  {'danceability': 0.897,
#   'energy': 0.522,
#   'key': 2,
#   'loudness': -7.578,
#   'mode': 1,
#   'speechiness': 0.374,
#   'acousticness': 0.0016,
#   'instrumentalness': 0,
#   'liveness': 0.0554,
#   'valence': 0.623,
#   'tempo': 149.986,
#   'type': 'audio_features',
#   'id': '00ko9WaS4jOX1kEk3gvHjf',
#   'uri': 'spotify:track:00ko9WaS4jOX1kEk3gvHjf',
#   'track_href': 'https://api.spotify.com/v1/tracks/00ko9WaS4jOX1kEk3gvHjf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00ko9WaS4jOX1kEk3gvHjf',
#   'duration_ms': 225924,
#   'time_signature': 4},
#  {'danceability': 0.686,
#   'energy': 0.561,
#   'key': 10,
#   'loudness': -9.929,
#   'mode': 0,
#   'speechiness': 0.191,
#   'acousticness': 0.185,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.186,
#   'tempo': 148.775,
#   'type': 'audio_features',
#   'id': '6alCTRgBPoeAFi2N4il9Q4',
#   'uri': 'spotify:track:6alCTRgBPoeAFi2N4il9Q4',
#   'track_href': 'https://api.spotify.com/v1/tracks/6alCTRgBPoeAFi2N4il9Q4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6alCTRgBPoeAFi2N4il9Q4',
#   'duration_ms': 116240,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.66,
#   'key': 0,
#   'loudness': -2.848,
#   'mode': 1,
#   'speechiness': 0.0441,
#   'acousticness': 0.19,
#   'instrumentalness': 0,
#   'liveness': 0.211,
#   'valence': 0.452,
#   'tempo': 145.01,
#   'type': 'audio_features',
#   'id': '2C6WXnmZ66tHhHlnvwePiK',
#   'uri': 'spotify:track:2C6WXnmZ66tHhHlnvwePiK',
#   'track_href': 'https://api.spotify.com/v1/tracks/2C6WXnmZ66tHhHlnvwePiK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2C6WXnmZ66tHhHlnvwePiK',
#   'duration_ms': 245267,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.317,
#   'key': 1,
#   'loudness': -10.732,
#   'mode': 0,
#   'speechiness': 0.334,
#   'acousticness': 0.592,
#   'instrumentalness': 0,
#   'liveness': 0.0881,
#   'valence': 0.327,
#   'tempo': 140.048,
#   'type': 'audio_features',
#   'id': '6ocbgoVGwYJhOv1GgI9NsF',
#   'uri': 'spotify:track:6ocbgoVGwYJhOv1GgI9NsF',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ocbgoVGwYJhOv1GgI9NsF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ocbgoVGwYJhOv1GgI9NsF',
#   'duration_ms': 178627,
#   'time_signature': 4},
#  {'danceability': 0.824,
#   'energy': 0.588,
#   'key': 6,
#   'loudness': -6.4,
#   'mode': 0,
#   'speechiness': 0.0924,
#   'acousticness': 0.692,
#   'instrumentalness': 0.000104,
#   'liveness': 0.149,
#   'valence': 0.513,
#   'tempo': 98.027,
#   'type': 'audio_features',
#   'id': '5ZULALImTm80tzUbYQYM9d',
#   'uri': 'spotify:track:5ZULALImTm80tzUbYQYM9d',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ZULALImTm80tzUbYQYM9d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ZULALImTm80tzUbYQYM9d',
#   'duration_ms': 209438,
#   'time_signature': 4},
#  {'danceability': 0.901,
#   'energy': 0.4,
#   'key': 0,
#   'loudness': -8.575,
#   'mode': 1,
#   'speechiness': 0.126,
#   'acousticness': 0.051,
#   'instrumentalness': 0,
#   'liveness': 0.0599,
#   'valence': 0.346,
#   'tempo': 135.984,
#   'type': 'audio_features',
#   'id': '6TqXcAFInzjp0bODyvrWEq',
#   'uri': 'spotify:track:6TqXcAFInzjp0bODyvrWEq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6TqXcAFInzjp0bODyvrWEq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6TqXcAFInzjp0bODyvrWEq',
#   'duration_ms': 197573,
#   'time_signature': 4},
#  {'danceability': 0.717,
#   'energy': 0.598,
#   'key': 5,
#   'loudness': -5.613,
#   'mode': 0,
#   'speechiness': 0.0809,
#   'acousticness': 0.22,
#   'instrumentalness': 0,
#   'liveness': 0.122,
#   'valence': 0.496,
#   'tempo': 153.905,
#   'type': 'audio_features',
#   'id': '4SDgTLDYrJ2UrHbkRkg7MD',
#   'uri': 'spotify:track:4SDgTLDYrJ2UrHbkRkg7MD',
#   'track_href': 'https://api.spotify.com/v1/tracks/4SDgTLDYrJ2UrHbkRkg7MD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SDgTLDYrJ2UrHbkRkg7MD',
#   'duration_ms': 151040,
#   'time_signature': 4},
#  {'danceability': 0.921,
#   'energy': 0.635,
#   'key': 1,
#   'loudness': -4.904,
#   'mode': 1,
#   'speechiness': 0.416,
#   'acousticness': 0.0218,
#   'instrumentalness': 0,
#   'liveness': 0.0946,
#   'valence': 0.549,
#   'tempo': 130.028,
#   'type': 'audio_features',
#   'id': '2rMAtCaTj16NptyVfEIeAC',
#   'uri': 'spotify:track:2rMAtCaTj16NptyVfEIeAC',
#   'track_href': 'https://api.spotify.com/v1/tracks/2rMAtCaTj16NptyVfEIeAC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2rMAtCaTj16NptyVfEIeAC',
#   'duration_ms': 192540,
#   'time_signature': 4},
#  {'danceability': 0.798,
#   'energy': 0.675,
#   'key': 6,
#   'loudness': -5.041,
#   'mode': 1,
#   'speechiness': 0.0442,
#   'acousticness': 0.0912,
#   'instrumentalness': 0,
#   'liveness': 0.0894,
#   'valence': 0.842,
#   'tempo': 101.956,
#   'type': 'audio_features',
#   'id': '3HVWdVOQ0ZA45FuZGSfvns',
#   'uri': 'spotify:track:3HVWdVOQ0ZA45FuZGSfvns',
#   'track_href': 'https://api.spotify.com/v1/tracks/3HVWdVOQ0ZA45FuZGSfvns',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HVWdVOQ0ZA45FuZGSfvns',
#   'duration_ms': 219947,
#   'time_signature': 4},
#  {'danceability': 0.852,
#   'energy': 0.73,
#   'key': 1,
#   'loudness': -5.803,
#   'mode': 1,
#   'speechiness': 0.0579,
#   'acousticness': 0.0219,
#   'instrumentalness': 0,
#   'liveness': 0.336,
#   'valence': 0.394,
#   'tempo': 92.506,
#   'type': 'audio_features',
#   'id': '7f1zjZG77S891Uv4O68yfk',
#   'uri': 'spotify:track:7f1zjZG77S891Uv4O68yfk',
#   'track_href': 'https://api.spotify.com/v1/tracks/7f1zjZG77S891Uv4O68yfk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7f1zjZG77S891Uv4O68yfk',
#   'duration_ms': 157693,
#   'time_signature': 4},
#  {'danceability': 0.685,
#   'energy': 0.692,
#   'key': 2,
#   'loudness': -5.122,
#   'mode': 1,
#   'speechiness': 0.0457,
#   'acousticness': 0.328,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.578,
#   'tempo': 159.966,
#   'type': 'audio_features',
#   'id': '6Hj9jySrnFppAI0sEMCZpJ',
#   'uri': 'spotify:track:6Hj9jySrnFppAI0sEMCZpJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Hj9jySrnFppAI0sEMCZpJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Hj9jySrnFppAI0sEMCZpJ',
#   'duration_ms': 240051,
#   'time_signature': 5},
#  {'danceability': 0.442,
#   'energy': 0.737,
#   'key': 7,
#   'loudness': -5.046,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.0589,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.21,
#   'tempo': 112.93,
#   'type': 'audio_features',
#   'id': '12Fkyg9lpmaz2zmKOfw2Y2',
#   'uri': 'spotify:track:12Fkyg9lpmaz2zmKOfw2Y2',
#   'track_href': 'https://api.spotify.com/v1/tracks/12Fkyg9lpmaz2zmKOfw2Y2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12Fkyg9lpmaz2zmKOfw2Y2',
#   'duration_ms': 218320,
#   'time_signature': 5},
#  {'danceability': 0.901,
#   'energy': 0.676,
#   'key': 2,
#   'loudness': -7.033,
#   'mode': 1,
#   'speechiness': 0.251,
#   'acousticness': 0.0646,
#   'instrumentalness': 0,
#   'liveness': 0.0863,
#   'valence': 0.452,
#   'tempo': 85.018,
#   'type': 'audio_features',
#   'id': '5rU6kDNXZLXIinFezpbWbO',
#   'uri': 'spotify:track:5rU6kDNXZLXIinFezpbWbO',
#   'track_href': 'https://api.spotify.com/v1/tracks/5rU6kDNXZLXIinFezpbWbO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rU6kDNXZLXIinFezpbWbO',
#   'duration_ms': 148278,
#   'time_signature': 4},
#  {'danceability': 0.682,
#   'energy': 0.559,
#   'key': 0,
#   'loudness': -5.545,
#   'mode': 1,
#   'speechiness': 0.127,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.344,
#   'valence': 0.137,
#   'tempo': 202.015,
#   'type': 'audio_features',
#   'id': '3j84U36KvLeXNDPv4t5pI8',
#   'uri': 'spotify:track:3j84U36KvLeXNDPv4t5pI8',
#   'track_href': 'https://api.spotify.com/v1/tracks/3j84U36KvLeXNDPv4t5pI8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3j84U36KvLeXNDPv4t5pI8',
#   'duration_ms': 192471,
#   'time_signature': 4},
#  {'danceability': 0.642,
#   'energy': 0.647,
#   'key': 7,
#   'loudness': -6.312,
#   'mode': 0,
#   'speechiness': 0.428,
#   'acousticness': 0.517,
#   'instrumentalness': 0,
#   'liveness': 0.0649,
#   'valence': 0.664,
#   'tempo': 120.749,
#   'type': 'audio_features',
#   'id': '5WnfnSpuNEGXyEt78PBA6d',
#   'uri': 'spotify:track:5WnfnSpuNEGXyEt78PBA6d',
#   'track_href': 'https://api.spotify.com/v1/tracks/5WnfnSpuNEGXyEt78PBA6d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5WnfnSpuNEGXyEt78PBA6d',
#   'duration_ms': 217867,
#   'time_signature': 4},
#  {'danceability': 0.829,
#   'energy': 0.582,
#   'key': 7,
#   'loudness': -5.721,
#   'mode': 0,
#   'speechiness': 0.0415,
#   'acousticness': 0.525,
#   'instrumentalness': 0,
#   'liveness': 0.0759,
#   'valence': 0.51,
#   'tempo': 108.028,
#   'type': 'audio_features',
#   'id': '5xjei7JnROsAzLY2a7RdZU',
#   'uri': 'spotify:track:5xjei7JnROsAzLY2a7RdZU',
#   'track_href': 'https://api.spotify.com/v1/tracks/5xjei7JnROsAzLY2a7RdZU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5xjei7JnROsAzLY2a7RdZU',
#   'duration_ms': 109373,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.646,
#   'key': 7,
#   'loudness': -5.795,
#   'mode': 1,
#   'speechiness': 0.317,
#   'acousticness': 0.152,
#   'instrumentalness': 1.85e-05,
#   'liveness': 0.108,
#   'valence': 0.429,
#   'tempo': 176.089,
#   'type': 'audio_features',
#   'id': '0fea68AdmYNygeTGI4RC18',
#   'uri': 'spotify:track:0fea68AdmYNygeTGI4RC18',
#   'track_href': 'https://api.spotify.com/v1/tracks/0fea68AdmYNygeTGI4RC18',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fea68AdmYNygeTGI4RC18',
#   'duration_ms': 242573,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.772,
#   'key': 6,
#   'loudness': -5.585,
#   'mode': 1,
#   'speechiness': 0.4,
#   'acousticness': 0.128,
#   'instrumentalness': 0,
#   'liveness': 0.157,
#   'valence': 0.678,
#   'tempo': 132.906,
#   'type': 'audio_features',
#   'id': '3WyRgi8CzQnhzO0xw79tTS',
#   'uri': 'spotify:track:3WyRgi8CzQnhzO0xw79tTS',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WyRgi8CzQnhzO0xw79tTS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WyRgi8CzQnhzO0xw79tTS',
#   'duration_ms': 141827,
#   'time_signature': 4},
#  {'danceability': 0.786,
#   'energy': 0.428,
#   'key': 5,
#   'loudness': -10.011,
#   'mode': 0,
#   'speechiness': 0.31,
#   'acousticness': 0.0933,
#   'instrumentalness': 1.1e-06,
#   'liveness': 0.156,
#   'valence': 0.556,
#   'tempo': 97.001,
#   'type': 'audio_features',
#   'id': '6PYnUsNEpYC7A4BS2sjw3L',
#   'uri': 'spotify:track:6PYnUsNEpYC7A4BS2sjw3L',
#   'track_href': 'https://api.spotify.com/v1/tracks/6PYnUsNEpYC7A4BS2sjw3L',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6PYnUsNEpYC7A4BS2sjw3L',
#   'duration_ms': 255000,
#   'time_signature': 4},
#  {'danceability': 0.764,
#   'energy': 0.555,
#   'key': 11,
#   'loudness': -6.414,
#   'mode': 1,
#   'speechiness': 0.0604,
#   'acousticness': 0.275,
#   'instrumentalness': 0,
#   'liveness': 0.0824,
#   'valence': 0.255,
#   'tempo': 111.004,
#   'type': 'audio_features',
#   'id': '0rFQ5cKYJ9WtHSKp9sxVYt',
#   'uri': 'spotify:track:0rFQ5cKYJ9WtHSKp9sxVYt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rFQ5cKYJ9WtHSKp9sxVYt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rFQ5cKYJ9WtHSKp9sxVYt',
#   'duration_ms': 169227,
#   'time_signature': 4},
#  {'danceability': 0.809,
#   'energy': 0.545,
#   'key': 7,
#   'loudness': -6.678,
#   'mode': 1,
#   'speechiness': 0.0735,
#   'acousticness': 0.392,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.244,
#   'tempo': 97.008,
#   'type': 'audio_features',
#   'id': '3QzAOrNlsabgbMwlZt7TAY',
#   'uri': 'spotify:track:3QzAOrNlsabgbMwlZt7TAY',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QzAOrNlsabgbMwlZt7TAY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QzAOrNlsabgbMwlZt7TAY',
#   'duration_ms': 180435,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.678,
#   'key': 8,
#   'loudness': -7.159,
#   'mode': 1,
#   'speechiness': 0.0324,
#   'acousticness': 0.0154,
#   'instrumentalness': 6.05e-06,
#   'liveness': 0.101,
#   'valence': 0.404,
#   'tempo': 103.952,
#   'type': 'audio_features',
#   'id': '6oJ6le65B3SEqPwMRNXWjY',
#   'uri': 'spotify:track:6oJ6le65B3SEqPwMRNXWjY',
#   'track_href': 'https://api.spotify.com/v1/tracks/6oJ6le65B3SEqPwMRNXWjY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6oJ6le65B3SEqPwMRNXWjY',
#   'duration_ms': 228267,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.679,
#   'key': 9,
#   'loudness': -5.614,
#   'mode': 1,
#   'speechiness': 0.0324,
#   'acousticness': 0.139,
#   'instrumentalness': 6.98e-05,
#   'liveness': 0.465,
#   'valence': 0.657,
#   'tempo': 140.081,
#   'type': 'audio_features',
#   'id': '4ak7xjvBeBOcJGWFDX9w5n',
#   'uri': 'spotify:track:4ak7xjvBeBOcJGWFDX9w5n',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ak7xjvBeBOcJGWFDX9w5n',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ak7xjvBeBOcJGWFDX9w5n',
#   'duration_ms': 158707,
#   'time_signature': 4},
#  {'danceability': 0.811,
#   'energy': 0.719,
#   'key': 9,
#   'loudness': -6.553,
#   'mode': 1,
#   'speechiness': 0.0497,
#   'acousticness': 0.0129,
#   'instrumentalness': 1.36e-05,
#   'liveness': 0.0742,
#   'valence': 0.865,
#   'tempo': 103.979,
#   'type': 'audio_features',
#   'id': '4y5bvROuBDPr5fuwXbIBZR',
#   'uri': 'spotify:track:4y5bvROuBDPr5fuwXbIBZR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4y5bvROuBDPr5fuwXbIBZR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4y5bvROuBDPr5fuwXbIBZR',
#   'duration_ms': 222400,
#   'time_signature': 4},
#  {'danceability': 0.493,
#   'energy': 0.665,
#   'key': 2,
#   'loudness': -6.427,
#   'mode': 0,
#   'speechiness': 0.366,
#   'acousticness': 0.0107,
#   'instrumentalness': 0,
#   'liveness': 0.0762,
#   'valence': 0.385,
#   'tempo': 179.982,
#   'type': 'audio_features',
#   'id': '0DZJACISivjWjscIp5Kg1q',
#   'uri': 'spotify:track:0DZJACISivjWjscIp5Kg1q',
#   'track_href': 'https://api.spotify.com/v1/tracks/0DZJACISivjWjscIp5Kg1q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0DZJACISivjWjscIp5Kg1q',
#   'duration_ms': 171227,
#   'time_signature': 4},
#  {'danceability': 0.692,
#   'energy': 0.809,
#   'key': 2,
#   'loudness': -4.198,
#   'mode': 1,
#   'speechiness': 0.0602,
#   'acousticness': 0.524,
#   'instrumentalness': 0,
#   'liveness': 0.147,
#   'valence': 0.864,
#   'tempo': 123.911,
#   'type': 'audio_features',
#   'id': '6LsAAHotRLMOHfCsSfYCsz',
#   'uri': 'spotify:track:6LsAAHotRLMOHfCsSfYCsz',
#   'track_href': 'https://api.spotify.com/v1/tracks/6LsAAHotRLMOHfCsSfYCsz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6LsAAHotRLMOHfCsSfYCsz',
#   'duration_ms': 190800,
#   'time_signature': 4},
#  {'danceability': 0.862,
#   'energy': 0.685,
#   'key': 0,
#   'loudness': -7.699,
#   'mode': 0,
#   'speechiness': 0.242,
#   'acousticness': 0.0342,
#   'instrumentalness': 0,
#   'liveness': 0.204,
#   'valence': 0.672,
#   'tempo': 100.024,
#   'type': 'audio_features',
#   'id': '05WepN8vrMLJG5r8XRdLeL',
#   'uri': 'spotify:track:05WepN8vrMLJG5r8XRdLeL',
#   'track_href': 'https://api.spotify.com/v1/tracks/05WepN8vrMLJG5r8XRdLeL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05WepN8vrMLJG5r8XRdLeL',
#   'duration_ms': 172800,
#   'time_signature': 4},
#  {'danceability': 0.767,
#   'energy': 0.889,
#   'key': 7,
#   'loudness': -2.988,
#   'mode': 1,
#   'speechiness': 0.0963,
#   'acousticness': 0.00611,
#   'instrumentalness': 0,
#   'liveness': 0.402,
#   'valence': 0.843,
#   'tempo': 119.93,
#   'type': 'audio_features',
#   'id': '0k664IuFwVP557Gnx7RhIl',
#   'uri': 'spotify:track:0k664IuFwVP557Gnx7RhIl',
#   'track_href': 'https://api.spotify.com/v1/tracks/0k664IuFwVP557Gnx7RhIl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0k664IuFwVP557Gnx7RhIl',
#   'duration_ms': 195145,
#   'time_signature': 4},
#  {'danceability': 0.847,
#   'energy': 0.678,
#   'key': 9,
#   'loudness': -8.635,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.0669,
#   'instrumentalness': 0,
#   'liveness': 0.274,
#   'valence': 0.811,
#   'tempo': 97.984,
#   'type': 'audio_features',
#   'id': '5dW1VZPcFqB4n0P08rGDgm',
#   'uri': 'spotify:track:5dW1VZPcFqB4n0P08rGDgm',
#   'track_href': 'https://api.spotify.com/v1/tracks/5dW1VZPcFqB4n0P08rGDgm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dW1VZPcFqB4n0P08rGDgm',
#   'duration_ms': 200594,
#   'time_signature': 4},
#  {'danceability': 0.829,
#   'energy': 0.539,
#   'key': 11,
#   'loudness': -7.359,
#   'mode': 0,
#   'speechiness': 0.208,
#   'acousticness': 0.136,
#   'instrumentalness': 1.78e-06,
#   'liveness': 0.103,
#   'valence': 0.388,
#   'tempo': 99.96,
#   'type': 'audio_features',
#   'id': '7xQAfvXzm3AkraOtGPWIZg',
#   'uri': 'spotify:track:7xQAfvXzm3AkraOtGPWIZg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7xQAfvXzm3AkraOtGPWIZg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xQAfvXzm3AkraOtGPWIZg',
#   'duration_ms': 149547,
#   'time_signature': 4},
#  {'danceability': 0.897,
#   'energy': 0.366,
#   'key': 0,
#   'loudness': -8.029,
#   'mode': 1,
#   'speechiness': 0.0569,
#   'acousticness': 0.00889,
#   'instrumentalness': 0.000353,
#   'liveness': 0.0715,
#   'valence': 0.416,
#   'tempo': 100.003,
#   'type': 'audio_features',
#   'id': '2YWtcWi3a83pdEg3Gif4Pd',
#   'uri': 'spotify:track:2YWtcWi3a83pdEg3Gif4Pd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2YWtcWi3a83pdEg3Gif4Pd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YWtcWi3a83pdEg3Gif4Pd',
#   'duration_ms': 173387,
#   'time_signature': 4},
#  {'danceability': 0.978,
#   'energy': 0.477,
#   'key': 8,
#   'loudness': -8.159,
#   'mode': 1,
#   'speechiness': 0.155,
#   'acousticness': 0.000143,
#   'instrumentalness': 0,
#   'liveness': 0.133,
#   'valence': 0.196,
#   'tempo': 110.002,
#   'type': 'audio_features',
#   'id': '3AEgic4yp82NxMWUjHtxnO',
#   'uri': 'spotify:track:3AEgic4yp82NxMWUjHtxnO',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AEgic4yp82NxMWUjHtxnO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AEgic4yp82NxMWUjHtxnO',
#   'duration_ms': 109091,
#   'time_signature': 4},
#  {'danceability': 0.905,
#   'energy': 0.389,
#   'key': 8,
#   'loudness': -14.505,
#   'mode': 1,
#   'speechiness': 0.332,
#   'acousticness': 0.74,
#   'instrumentalness': 0.162,
#   'liveness': 0.106,
#   'valence': 0.196,
#   'tempo': 120.046,
#   'type': 'audio_features',
#   'id': '4SSnFejRGlZikf02HLewEF',
#   'uri': 'spotify:track:4SSnFejRGlZikf02HLewEF',
#   'track_href': 'https://api.spotify.com/v1/tracks/4SSnFejRGlZikf02HLewEF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SSnFejRGlZikf02HLewEF',
#   'duration_ms': 193143,
#   'time_signature': 4},
#  {'danceability': 0.717,
#   'energy': 0.653,
#   'key': 1,
#   'loudness': -5.634,
#   'mode': 1,
#   'speechiness': 0.0658,
#   'acousticness': 0.229,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.412,
#   'tempo': 106.966,
#   'type': 'audio_features',
#   'id': '3e9HZxeyfWwjeyPAMmWSSQ',
#   'uri': 'spotify:track:3e9HZxeyfWwjeyPAMmWSSQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3e9HZxeyfWwjeyPAMmWSSQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3e9HZxeyfWwjeyPAMmWSSQ',
#   'duration_ms': 207320,
#   'time_signature': 4},
#  {'danceability': 0.632,
#   'energy': 0.732,
#   'key': 6,
#   'loudness': -3.498,
#   'mode': 1,
# ...
#  {'danceability': 0.574,
#   'energy': 0.612,
#   'key': 0,
#   'loudness': -4.741,
#   'mode': 1,
#   'speechiness': 0.0781,
#   'acousticness': 0.357,
#   'instrumentalness': 0,
#   'liveness': 0.158,
#   'valence': 0.368,
#   'tempo': 136.046,
#   'type': 'audio_features',
#   'id': '2zoNNEAyPK2OGDfajardlY',
#   'uri': 'spotify:track:2zoNNEAyPK2OGDfajardlY',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zoNNEAyPK2OGDfajardlY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zoNNEAyPK2OGDfajardlY',
#   'duration_ms': 231663,
#   'time_signature': 3},
#  {'danceability': 0.637,
#   'energy': 0.723,
#   'key': 2,
#   'loudness': -5.547,
#   'mode': 1,
#   'speechiness': 0.091,
#   'acousticness': 0.0134,
#   'instrumentalness': 7.87e-05,
#   'liveness': 0.196,
#   'valence': 0.228,
#   'tempo': 143.013,
#   'type': 'audio_features',
#   'id': '0fIffclhgJC5h8AdMMVvkp',
#   'uri': 'spotify:track:0fIffclhgJC5h8AdMMVvkp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0fIffclhgJC5h8AdMMVvkp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fIffclhgJC5h8AdMMVvkp',
#   'duration_ms': 214960,
#   'time_signature': 4},
#  {'danceability': 0.808,
#   'energy': 0.907,
#   'key': 0,
#   'loudness': -4.027,
#   'mode': 0,
#   'speechiness': 0.0865,
#   'acousticness': 0.0592,
#   'instrumentalness': 0,
#   'liveness': 0.139,
#   'valence': 0.721,
#   'tempo': 158.994,
#   'type': 'audio_features',
#   'id': '3aaRK3htdVkK2pqOI64FEb',
#   'uri': 'spotify:track:3aaRK3htdVkK2pqOI64FEb',
#   'track_href': 'https://api.spotify.com/v1/tracks/3aaRK3htdVkK2pqOI64FEb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3aaRK3htdVkK2pqOI64FEb',
#   'duration_ms': 180447,
#   'time_signature': 4},
#  {'danceability': 0.745,
#   'energy': 0.693,
#   'key': 2,
#   'loudness': -5.479,
#   'mode': 0,
#   'speechiness': 0.034,
#   'acousticness': 0.339,
#   'instrumentalness': 0,
#   'liveness': 0.123,
#   'valence': 0.248,
#   'tempo': 98.039,
#   'type': 'audio_features',
#   'id': '2XWjPtKdi5sucFYtVav07d',
#   'uri': 'spotify:track:2XWjPtKdi5sucFYtVav07d',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XWjPtKdi5sucFYtVav07d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XWjPtKdi5sucFYtVav07d',
#   'duration_ms': 181900,
#   'time_signature': 4},
#  {'danceability': 0.618,
#   'energy': 0.695,
#   'key': 7,
#   'loudness': -5.415,
#   'mode': 1,
#   'speechiness': 0.189,
#   'acousticness': 0.211,
#   'instrumentalness': 3.96e-05,
#   'liveness': 0.11,
#   'valence': 0.766,
#   'tempo': 199.95,
#   'type': 'audio_features',
#   'id': '3D4uUFRoYDFHbkQlTKL2Om',
#   'uri': 'spotify:track:3D4uUFRoYDFHbkQlTKL2Om',
#   'track_href': 'https://api.spotify.com/v1/tracks/3D4uUFRoYDFHbkQlTKL2Om',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3D4uUFRoYDFHbkQlTKL2Om',
#   'duration_ms': 226720,
#   'time_signature': 3},
#  {'danceability': 0.425,
#   'energy': 0.547,
#   'key': 7,
#   'loudness': -6.453,
#   'mode': 1,
#   'speechiness': 0.042,
#   'acousticness': 0.397,
#   'instrumentalness': 0,
#   'liveness': 0.755,
#   'valence': 0.742,
#   'tempo': 84.474,
#   'type': 'audio_features',
#   'id': '4J6xwl0UkdQOjAuV2gBAbl',
#   'uri': 'spotify:track:4J6xwl0UkdQOjAuV2gBAbl',
#   'track_href': 'https://api.spotify.com/v1/tracks/4J6xwl0UkdQOjAuV2gBAbl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4J6xwl0UkdQOjAuV2gBAbl',
#   'duration_ms': 172267,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.597,
#   'key': 3,
#   'loudness': -6.21,
#   'mode': 0,
#   'speechiness': 0.0686,
#   'acousticness': 0.0725,
#   'instrumentalness': 0,
#   'liveness': 0.0954,
#   'valence': 0.239,
#   'tempo': 82.134,
#   'type': 'audio_features',
#   'id': '1IRU2kqvCmmySoB0ywJTmI',
#   'uri': 'spotify:track:1IRU2kqvCmmySoB0ywJTmI',
#   'track_href': 'https://api.spotify.com/v1/tracks/1IRU2kqvCmmySoB0ywJTmI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1IRU2kqvCmmySoB0ywJTmI',
#   'duration_ms': 234147,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.622,
#   'key': 6,
#   'loudness': -7.689,
#   'mode': 0,
#   'speechiness': 0.14,
#   'acousticness': 0.324,
#   'instrumentalness': 0,
#   'liveness': 0.165,
#   'valence': 0.729,
#   'tempo': 143.934,
#   'type': 'audio_features',
#   'id': '3qOkkP9JLltoUvaLjEXTmW',
#   'uri': 'spotify:track:3qOkkP9JLltoUvaLjEXTmW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qOkkP9JLltoUvaLjEXTmW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qOkkP9JLltoUvaLjEXTmW',
#   'duration_ms': 169600,
#   'time_signature': 4},
#  {'danceability': 0.402,
#   'energy': 0.754,
#   'key': 0,
#   'loudness': -5.268,
#   'mode': 1,
#   'speechiness': 0.0571,
#   'acousticness': 0.0394,
#   'instrumentalness': 0,
#   'liveness': 0.128,
#   'valence': 0.502,
#   'tempo': 173.887,
#   'type': 'audio_features',
#   'id': '5cuYa1jn3hohHZJCGC0B7d',
#   'uri': 'spotify:track:5cuYa1jn3hohHZJCGC0B7d',
#   'track_href': 'https://api.spotify.com/v1/tracks/5cuYa1jn3hohHZJCGC0B7d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cuYa1jn3hohHZJCGC0B7d',
#   'duration_ms': 199629,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.327,
#   'key': 11,
#   'loudness': -8.285,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.761,
#   'instrumentalness': 2.96e-05,
#   'liveness': 0.103,
#   'valence': 0.381,
#   'tempo': 74.953,
#   'type': 'audio_features',
#   'id': '1TQXIltqoZ5XXyfCbAeSQQ',
#   'uri': 'spotify:track:1TQXIltqoZ5XXyfCbAeSQQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1TQXIltqoZ5XXyfCbAeSQQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1TQXIltqoZ5XXyfCbAeSQQ',
#   'duration_ms': 197732,
#   'time_signature': 4},
#  {'danceability': 0.555,
#   'energy': 0.923,
#   'key': 6,
#   'loudness': -4.748,
#   'mode': 0,
#   'speechiness': 0.161,
#   'acousticness': 0.197,
#   'instrumentalness': 0,
#   'liveness': 0.0778,
#   'valence': 0.363,
#   'tempo': 118.007,
#   'type': 'audio_features',
#   'id': '6Tt1P5CLUrl59oSOTVxON0',
#   'uri': 'spotify:track:6Tt1P5CLUrl59oSOTVxON0',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Tt1P5CLUrl59oSOTVxON0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Tt1P5CLUrl59oSOTVxON0',
#   'duration_ms': 192681,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.653,
#   'key': 7,
#   'loudness': -5.095,
#   'mode': 1,
#   'speechiness': 0.0611,
#   'acousticness': 0.0944,
#   'instrumentalness': 0,
#   'liveness': 0.383,
#   'valence': 0.379,
#   'tempo': 123.084,
#   'type': 'audio_features',
#   'id': '7hzlzoOwCZ4D3Ow5YZK4kj',
#   'uri': 'spotify:track:7hzlzoOwCZ4D3Ow5YZK4kj',
#   'track_href': 'https://api.spotify.com/v1/tracks/7hzlzoOwCZ4D3Ow5YZK4kj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hzlzoOwCZ4D3Ow5YZK4kj',
#   'duration_ms': 179746,
#   'time_signature': 4},
#  {'danceability': 0.776,
#   'energy': 0.735,
#   'key': 1,
#   'loudness': -4.229,
#   'mode': 1,
#   'speechiness': 0.254,
#   'acousticness': 0.0531,
#   'instrumentalness': 9.91e-05,
#   'liveness': 0.153,
#   'valence': 0.519,
#   'tempo': 102.064,
#   'type': 'audio_features',
#   'id': '7u9CKCgpGAm9UiSXQ70I46',
#   'uri': 'spotify:track:7u9CKCgpGAm9UiSXQ70I46',
#   'track_href': 'https://api.spotify.com/v1/tracks/7u9CKCgpGAm9UiSXQ70I46',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7u9CKCgpGAm9UiSXQ70I46',
#   'duration_ms': 187072,
#   'time_signature': 4},
#  {'danceability': 0.631,
#   'energy': 0.796,
#   'key': 1,
#   'loudness': -5.35,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.000245,
#   'instrumentalness': 0.0115,
#   'liveness': 0.38,
#   'valence': 0.596,
#   'tempo': 92.469,
#   'type': 'audio_features',
#   'id': '7hvO2qCwJVZxiyoA7c9i5d',
#   'uri': 'spotify:track:7hvO2qCwJVZxiyoA7c9i5d',
#   'track_href': 'https://api.spotify.com/v1/tracks/7hvO2qCwJVZxiyoA7c9i5d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hvO2qCwJVZxiyoA7c9i5d',
#   'duration_ms': 209120,
#   'time_signature': 4},
#  {'danceability': 0.569,
#   'energy': 0.414,
#   'key': 10,
#   'loudness': -8.901,
#   'mode': 1,
#   'speechiness': 0.0758,
#   'acousticness': 0.633,
#   'instrumentalness': 0,
#   'liveness': 0.0916,
#   'valence': 0.35,
#   'tempo': 168.029,
#   'type': 'audio_features',
#   'id': '0W5oXFrxZNBTIS1eMW9Ofz',
#   'uri': 'spotify:track:0W5oXFrxZNBTIS1eMW9Ofz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0W5oXFrxZNBTIS1eMW9Ofz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0W5oXFrxZNBTIS1eMW9Ofz',
#   'duration_ms': 211103,
#   'time_signature': 4},
#  {'danceability': 0.369,
#   'energy': 0.609,
#   'key': 9,
#   'loudness': -4.477,
#   'mode': 0,
#   'speechiness': 0.184,
#   'acousticness': 0.259,
#   'instrumentalness': 4.1e-05,
#   'liveness': 0.133,
#   'valence': 0.381,
#   'tempo': 80.362,
#   'type': 'audio_features',
#   'id': '4BOikd4oZjOYMde9AXfrTo',
#   'uri': 'spotify:track:4BOikd4oZjOYMde9AXfrTo',
#   'track_href': 'https://api.spotify.com/v1/tracks/4BOikd4oZjOYMde9AXfrTo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BOikd4oZjOYMde9AXfrTo',
#   'duration_ms': 181140,
#   'time_signature': 1},
#  {'danceability': 0.774,
#   'energy': 0.466,
#   'key': 4,
#   'loudness': -6.869,
#   'mode': 1,
#   'speechiness': 0.0433,
#   'acousticness': 0.458,
#   'instrumentalness': 0,
#   'liveness': 0.111,
#   'valence': 0.396,
#   'tempo': 97.975,
#   'type': 'audio_features',
#   'id': '0ND8rF8oirMXtE59n585P6',
#   'uri': 'spotify:track:0ND8rF8oirMXtE59n585P6',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ND8rF8oirMXtE59n585P6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ND8rF8oirMXtE59n585P6',
#   'duration_ms': 182800,
#   'time_signature': 4},
#  {'danceability': 0.635,
#   'energy': 0.312,
#   'key': 7,
#   'loudness': -8.134,
#   'mode': 1,
#   'speechiness': 0.0265,
#   'acousticness': 0.635,
#   'instrumentalness': 0,
#   'liveness': 0.138,
#   'valence': 0.414,
#   'tempo': 98.017,
#   'type': 'audio_features',
#   'id': '6eDfe957aV4sqGnDhlSikJ',
#   'uri': 'spotify:track:6eDfe957aV4sqGnDhlSikJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6eDfe957aV4sqGnDhlSikJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6eDfe957aV4sqGnDhlSikJ',
#   'duration_ms': 240118,
#   'time_signature': 4},
#  {'danceability': 0.462,
#   'energy': 0.912,
#   'key': 11,
#   'loudness': -4.07,
#   'mode': 0,
#   'speechiness': 0.226,
#   'acousticness': 0.000138,
#   'instrumentalness': 0,
#   'liveness': 0.0357,
#   'valence': 0.722,
#   'tempo': 163.937,
#   'type': 'audio_features',
#   'id': '4r59yc67nric1MZQ2igkhx',
#   'uri': 'spotify:track:4r59yc67nric1MZQ2igkhx',
#   'track_href': 'https://api.spotify.com/v1/tracks/4r59yc67nric1MZQ2igkhx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4r59yc67nric1MZQ2igkhx',
#   'duration_ms': 151363,
#   'time_signature': 4},
#  {'danceability': 0.595,
#   'energy': 0.894,
#   'key': 7,
#   'loudness': -4.712,
#   'mode': 1,
#   'speechiness': 0.0493,
#   'acousticness': 0.00368,
#   'instrumentalness': 4.27e-06,
#   'liveness': 0.0491,
#   'valence': 0.768,
#   'tempo': 135.05,
#   'type': 'audio_features',
#   'id': '6ATDrk56ouL2eCxrgfDeHE',
#   'uri': 'spotify:track:6ATDrk56ouL2eCxrgfDeHE',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ATDrk56ouL2eCxrgfDeHE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ATDrk56ouL2eCxrgfDeHE',
#   'duration_ms': 177216,
#   'time_signature': 4},
#  {'danceability': 0.679,
#   'energy': 0.617,
#   'key': 0,
#   'loudness': -5.328,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.19,
#   'instrumentalness': 0,
#   'liveness': 0.0798,
#   'valence': 0.665,
#   'tempo': 189.993,
#   'type': 'audio_features',
#   'id': '0REjFxlMJRQxPqWSdmXiAT',
#   'uri': 'spotify:track:0REjFxlMJRQxPqWSdmXiAT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0REjFxlMJRQxPqWSdmXiAT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0REjFxlMJRQxPqWSdmXiAT',
#   'duration_ms': 228760,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.665,
#   'key': 2,
#   'loudness': -6.998,
#   'mode': 1,
#   'speechiness': 0.372,
#   'acousticness': 0.197,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.222,
#   'tempo': 96.016,
#   'type': 'audio_features',
#   'id': '6XH0KeCZ0nRysAeSJYRFFg',
#   'uri': 'spotify:track:6XH0KeCZ0nRysAeSJYRFFg',
#   'track_href': 'https://api.spotify.com/v1/tracks/6XH0KeCZ0nRysAeSJYRFFg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6XH0KeCZ0nRysAeSJYRFFg',
#   'duration_ms': 285015,
#   'time_signature': 4},
#  {'danceability': 0.623,
#   'energy': 0.615,
#   'key': 1,
#   'loudness': -10.064,
#   'mode': 1,
#   'speechiness': 0.146,
#   'acousticness': 0.304,
#   'instrumentalness': 0.00874,
#   'liveness': 0.25,
#   'valence': 0.672,
#   'tempo': 169.137,
#   'type': 'audio_features',
#   'id': '0anZ7olFcAsmx5hP517Rwn',
#   'uri': 'spotify:track:0anZ7olFcAsmx5hP517Rwn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0anZ7olFcAsmx5hP517Rwn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0anZ7olFcAsmx5hP517Rwn',
#   'duration_ms': 157303,
#   'time_signature': 4},
#  {'danceability': 0.819,
#   'energy': 0.596,
#   'key': 2,
#   'loudness': -7.009,
#   'mode': 1,
#   'speechiness': 0.318,
#   'acousticness': 0.225,
#   'instrumentalness': 1.19e-06,
#   'liveness': 0.138,
#   'valence': 0.622,
#   'tempo': 165.951,
#   'type': 'audio_features',
#   'id': '7q3NthaBqFI6s0WnAlnIvq',
#   'uri': 'spotify:track:7q3NthaBqFI6s0WnAlnIvq',
#   'track_href': 'https://api.spotify.com/v1/tracks/7q3NthaBqFI6s0WnAlnIvq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7q3NthaBqFI6s0WnAlnIvq',
#   'duration_ms': 225542,
#   'time_signature': 4},
#  {'danceability': 0.822,
#   'energy': 0.598,
#   'key': 4,
#   'loudness': -6.804,
#   'mode': 0,
#   'speechiness': 0.37,
#   'acousticness': 0.319,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.595,
#   'tempo': 176.046,
#   'type': 'audio_features',
#   'id': '1CHhAINmT48RpXE5owAo3Q',
#   'uri': 'spotify:track:1CHhAINmT48RpXE5owAo3Q',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CHhAINmT48RpXE5owAo3Q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CHhAINmT48RpXE5owAo3Q',
#   'duration_ms': 186784,
#   'time_signature': 4},
#  {'danceability': 0.522,
#   'energy': 0.716,
#   'key': 1,
#   'loudness': -4.146,
#   'mode': 1,
#   'speechiness': 0.279,
#   'acousticness': 0.0611,
#   'instrumentalness': 7.54e-06,
#   'liveness': 0.145,
#   'valence': 0.757,
#   'tempo': 149.929,
#   'type': 'audio_features',
#   'id': '4GjWnMNMN2EO76juYs9iWK',
#   'uri': 'spotify:track:4GjWnMNMN2EO76juYs9iWK',
#   'track_href': 'https://api.spotify.com/v1/tracks/4GjWnMNMN2EO76juYs9iWK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4GjWnMNMN2EO76juYs9iWK',
#   'duration_ms': 148293,
#   'time_signature': 4},
#  {'danceability': 0.434,
#   'energy': 0.231,
#   'key': 0,
#   'loudness': -16.314,
#   'mode': 1,
#   'speechiness': 0.0552,
#   'acousticness': 0.584,
#   'instrumentalness': 0.0218,
#   'liveness': 0.122,
#   'valence': 0.0774,
#   'tempo': 82.041,
#   'type': 'audio_features',
#   'id': '4454AwPZEKvSObvkwUGhcM',
#   'uri': 'spotify:track:4454AwPZEKvSObvkwUGhcM',
#   'track_href': 'https://api.spotify.com/v1/tracks/4454AwPZEKvSObvkwUGhcM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4454AwPZEKvSObvkwUGhcM',
#   'duration_ms': 193101,
#   'time_signature': 3},
#  {'danceability': 0.193,
#   'energy': 0.0453,
#   'key': 7,
#   'loudness': -26.219,
#   'mode': 1,
#   'speechiness': 0.0577,
#   'acousticness': 0.952,
#   'instrumentalness': 0.961,
#   'liveness': 0.104,
#   'valence': 0.119,
#   'tempo': 67.675,
#   'type': 'audio_features',
#   'id': '55EbjQa4Th0gmzKQdSnMrw',
#   'uri': 'spotify:track:55EbjQa4Th0gmzKQdSnMrw',
#   'track_href': 'https://api.spotify.com/v1/tracks/55EbjQa4Th0gmzKQdSnMrw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/55EbjQa4Th0gmzKQdSnMrw',
#   'duration_ms': 247258,
#   'time_signature': 4},
#  {'danceability': 0.509,
#   'energy': 0.183,
#   'key': 10,
#   'loudness': -10.27,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'acousticness': 0.946,
#   'instrumentalness': 0,
#   'liveness': 0.0914,
#   'valence': 0.258,
#   'tempo': 117.354,
#   'type': 'audio_features',
#   'id': '6H7fWtwEUHVfTyZD7zeG4w',
#   'uri': 'spotify:track:6H7fWtwEUHVfTyZD7zeG4w',
#   'track_href': 'https://api.spotify.com/v1/tracks/6H7fWtwEUHVfTyZD7zeG4w',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6H7fWtwEUHVfTyZD7zeG4w',
#   'duration_ms': 232837,
#   'time_signature': 3},
#  ...]

# %% [markdown]
# ## Good, now lets wrangle!
#
# Lets create a dataframe with the audio features

# %%
df_audio_features = pd.DataFrame.from_dict(rows, orient = "columns")

# %%
df_audio_features

df_audio_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8654 entries, 0 to 8653
# Data columns (total 18 columns):
# danceability        8654 non-null float64
# energy              8654 non-null float64
# key                 8654 non-null int64
# loudness            8654 non-null float64
# mode                8654 non-null int64
# speechiness         8654 non-null float64
# acousticness        8654 non-null float64
# instrumentalness    8654 non-null float64
# liveness            8654 non-null float64
# valence             8654 non-null float64
# tempo               8654 non-null float64
# type                8654 non-null object
# id                  8654 non-null object
# uri                 8654 non-null object
# track_href          8654 non-null object
# analysis_url        8654 non-null object
# duration_ms         8654 non-null int64
# time_signature      8654 non-null int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 1.2+ MB

# %%
# lets drop a few columns
col_2_drop = ["type", "uri", "analysis_url", "track_href"]
df_audio_features.drop(col_2_drop, axis = 1, inplace = True)
df_audio_features.rename(columns = {"id": "track_id"}, inplace = True)

# %%
df_audio_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.715   0.624    4    -3.046     0       0.1140        0.1100
# 1            0.831   0.502   10    -4.045     0       0.0460        0.1010
# 2            0.759   0.540    9    -6.039     0       0.0287        0.0370
# 3            0.703   0.594    5    -6.146     0       0.0752        0.3420
# 4            0.695   0.762    0    -3.497     1       0.0395        0.1920
# ...            ...     ...  ...       ...   ...          ...           ...
# 8649         0.786   0.633   10    -4.493     1       0.0330        0.0492
# 8650         0.433   0.934    5    -3.964     0       0.0481        0.0586
# 8651         0.971   0.464    8   -12.080     1       0.2040        0.1260
# 8652         0.639   0.822    6    -5.433     1       0.0500        0.0309
# 8653         0.547   0.271    0   -11.704     1       0.0315        0.3210
#
#       instrumentalness  liveness  valence    tempo                track_id  \
# 0             0.000000    0.1230    0.412  158.087  5qmq61DAAOUaW8AUo8xKhh
# 1             0.000000    0.1220    0.101  100.541  5ry2OE6R2zPQFDO85XkgRb
# 2             0.000000    0.0945    0.750  116.947  0TK2YIli7K1leLovkQiNik
# 3             0.000000    0.1230    0.475  153.848  6fTt0CH2t0mdeB2N9XFG5r
# 4             0.002440    0.0863    0.553  120.042  21jGcNKet2qwijlDFuPiPb
# ...                ...       ...      ...      ...                     ...
# 8649          0.000002    0.1140    0.945  120.005  5HClkiFAXSRSeMMofbNDGQ
# 8650          0.000918    0.6120    0.329  144.982  4smyx0T0iz2Ro9WFRlSo2p
# 8651          0.000000    0.0844    0.479  120.006  6BPB4N2FyFyrw91TVB1hMN
# 8652          0.000003    0.0286    0.824  141.989  3mPcoABQe29FXcYORjbVRr
# 8653          0.000085    0.0943    0.176  116.934  4eJZgQxgP1qxW5iLJKqOQQ
#
#       duration_ms  time_signature
# 0          173325               4
# 1          205427               4
# 2          190960               4
# 3          114893               4
# 4          215280               4
# ...           ...             ...
# 8649       208320               4
# 8650       294621               4
# 8651       208576               4
# 8652       190707               4
# 8653       181515               3
#
# [8654 rows x 14 columns]

# %%
# lets see if there are any duplicates still present. There shouldn't be.
any(df_audio_features.duplicated(subset = ["track_id"], keep = False) == True)

#good
# Out:
# False

# %% [markdown]
# ### Let's merge

# %%
df = pd.merge(df_tracks, df_audio_features, on = "track_id", how = "inner")

# %%
df
# Out:
#                           artist                                     track  \
# 0                          Lizzo                               Truth Hurts
# 1                          Drake  Money In The Grave (Drake ft. Rick Ross)
# 2                   Shawn Mendes                                  Señorita
# 3                      Lil Nas X                                    Panini
# 4                    Post Malone                                   Circles
# ...                          ...                                       ...
# 9438  La Poderosa Banda San Juan                                 Malabares
# 9439              Above & Beyond    There's Only You - Crystal Skies Remix
# 9440                 Iggy Azalea                                 Clap Back
# 9441           Dillon Carmichael              99 Problems (Fish Ain't One)
# 9442                  Koe Wetzel                     She Can't Stop Crying
#
#                     track_id  popularity  danceability  energy  key  loudness  \
# 0     5qmq61DAAOUaW8AUo8xKhh          94         0.715   0.624    4    -3.046
# 1     5ry2OE6R2zPQFDO85XkgRb          93         0.831   0.502   10    -4.045
# 2     0TK2YIli7K1leLovkQiNik         100         0.759   0.540    9    -6.039
# 3     6fTt0CH2t0mdeB2N9XFG5r          93         0.703   0.594    5    -6.146
# 4     21jGcNKet2qwijlDFuPiPb          94         0.695   0.762    0    -3.497
# ...                      ...         ...           ...     ...  ...       ...
# 9438  5HClkiFAXSRSeMMofbNDGQ          57         0.786   0.633   10    -4.493
# 9439  4smyx0T0iz2Ro9WFRlSo2p          53         0.433   0.934    5    -3.964
# 9440  6BPB4N2FyFyrw91TVB1hMN          54         0.971   0.464    8   -12.080
# 9441  3mPcoABQe29FXcYORjbVRr          49         0.639   0.822    6    -5.433
# 9442  4eJZgQxgP1qxW5iLJKqOQQ          48         0.547   0.271    0   -11.704
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        0       0.1140        0.1100          0.000000    0.1230    0.412
# 1        0       0.0460        0.1010          0.000000    0.1220    0.101
# 2        0       0.0287        0.0370          0.000000    0.0945    0.750
# 3        0       0.0752        0.3420          0.000000    0.1230    0.475
# 4        1       0.0395        0.1920          0.002440    0.0863    0.553
# ...    ...          ...           ...               ...       ...      ...
# 9438     1       0.0330        0.0492          0.000002    0.1140    0.945
# 9439     0       0.0481        0.0586          0.000918    0.6120    0.329
# 9440     1       0.2040        0.1260          0.000000    0.0844    0.479
# 9441     1       0.0500        0.0309          0.000003    0.0286    0.824
# 9442     1       0.0315        0.3210          0.000085    0.0943    0.176
#
#         tempo  duration_ms  time_signature
# 0     158.087       173325               4
# 1     100.541       205427               4
# 2     116.947       190960               4
# 3     153.848       114893               4
# 4     120.042       215280               4
# ...       ...          ...             ...
# 9438  120.005       208320               4
# 9439  144.982       294621               4
# 9440  120.006       208576               4
# 9441  141.989       190707               4
# 9442  116.934       181515               3
#
# [9443 rows x 17 columns]

# %%
# great this works, lets save it
df.to_csv("full_dataframe_oct2.csv")
